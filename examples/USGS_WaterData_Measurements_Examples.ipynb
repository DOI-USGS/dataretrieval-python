# %% [markdown]
# # USGS dataretrieval Python Package `get_field_measurements()` Examples
#
# This notebook provides examples of using the Python dataretrieval package to retrieve surface water field measurement data for a United States Geological Survey (USGS) monitoring location. The dataretrieval package provides a collection of functions to get data from the USGS Water Data API and other online sources of hydrology and water quality data.

# %% [markdown]
# ### Install the Package
#
# Use the following code to install the package if it doesn't exist already within your Jupyter Python environment.

# %%
# !pip install dataretrieval
# Out:
# Requirement already satisfied: dataretrieval in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (0.1.dev1+gff8f5354d)
# Requirement already satisfied: httpx in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from dataretrieval) (0.28.1)
# Requirement already satisfied: pandas<4.0.0,>=2.0.0 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from dataretrieval) (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from pandas<4.0.0,>=2.0.0->dataretrieval) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from pandas<4.0.0,>=2.0.0->dataretrieval) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<4.0.0,>=2.0.0->dataretrieval) (1.17.0)
# Requirement already satisfied: anyio in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (4.13.0)
# Requirement already satisfied: certifi in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (1.0.9)
# Requirement already satisfied: idna in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpcore==1.*->httpx->dataretrieval) (0.16.0)

# %% [markdown]
# Load the package so you can use it along with other packages used in this notebook.

# %%
from IPython.display import display

import dataretrieval.waterdata as waterdata

# %% [markdown]
# ### Basic Usage
#
# The dataretrieval package has several functions that allow you to retrieve data from the USGS Water Data API. This example uses the `get_field_measurements()` function to retrieve surface water field measurements for a USGS monitoring location. Field measurements are physically measured values (such as gage height and discharge) collected during a visit to a monitoring location, and are primarily used as calibration readings for the automated sensors collecting continuous data. The function accepts the following arguments (all optional):
#
# * **monitoring_location_id** (string or list of strings): A unique identifier representing a single monitoring location, formed by combining the responsible agency code with the location ID number, separated by a hyphen (e.g. `USGS-10109000`). A list may be supplied to query multiple locations.
# * **parameter_code** (string or list of strings): One or more 5-digit parameter codes identifying the constituent measured and its units of measure.
# * **time** (string): The date an observation represents. Accepts an RFC 3339 date-time, a bounded or half-bounded interval (e.g. `2019-01-01/2019-12-31` or `2019-01-01/..`), or an ISO 8601 duration (e.g. `P20Y` for the past 20 years).
# * **skip_geometry** (boolean): If `True`, response geometries are omitted and a plain (non-spatial) data frame is returned.
#
# Additional query parameters such as `approval_status`, `qualifier`, `bbox`, and `limit` are also supported; see the `get_field_measurements()` docstring for the full list.

# %% [markdown]
# Example 1: Get all of the field measurements for a single monitoring location

# %%
measurements1 = waterdata.get_field_measurements(monitoring_location_id="USGS-10109000")
print("Retrieved " + str(len(measurements1[0])) + " data values.")
# Out:
# Retrieving: field-measurements · 1 page · 1,918 rows
# No API key detected — register for higher rate limits at https://api.waterdata.usgs.gov/signup/
# Retrieved 1918 data values.

# %% [markdown]
# ### Interpreting the Result
#
# The `get_field_measurements()` function returns a tuple of two objects: a pandas data frame and an associated metadata object. The data frame is flat, uses a default integer index, and contains a `time` column holding the date of each measurement (along with columns such as `monitoring_location_id`, `parameter_code`, `value`, and `unit_of_measure`).
#
# Once you've got the data frame, there are several useful things you can do to explore the data.

# %% [markdown]
# Display the data frame as a table

# %%
display(measurements1[0])
# Out:
#                          geometry          field_measurements_series_id  \
# 0     POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 1     POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 2     POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 3     POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 4     POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# ...                           ...                                   ...
# 1913  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 1914  POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 1915  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 1916  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 1917  POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
#
#                             field_visit_id parameter_code  \
# 0     4cd21ba9-8644-ebfc-e053-0100007fd6db          00060
# 1     4cd21ba9-8644-ebfc-e053-0100007fd6db          00065
# 2     4cd21977-d55d-efa9-e053-0100007fcc60          00060
# 3     4cd21977-d55d-efa9-e053-0100007fcc60          00065
# 4     4cd21ba9-8645-ebfc-e053-0100007fd6db          00065
# ...                                    ...            ...
# 1913  98c59f70-ce2c-4a4d-9acf-18a179a96c78          00065
# 1914  6e48b7b6-152b-4a98-a974-87adf3d0ddc8          00060
# 1915  6e48b7b6-152b-4a98-a974-87adf3d0ddc8          00065
# 1916  20adb970-eb0a-4892-b5f2-92e7d1678b73          00065
# 1917  20adb970-eb0a-4892-b5f2-92e7d1678b73          00060
#
#      monitoring_location_id observing_procedure_code  \
# 0             USGS-10109000                        Z
# 1             USGS-10109000                        Z
# 2             USGS-10109000                        Z
# 3             USGS-10109000                        Z
# 4             USGS-10109000                        Z
# ...                     ...                      ...
# 1913          USGS-10109000                        Z
# 1914          USGS-10109000                        Z
# 1915          USGS-10109000                        Z
# 1916          USGS-10109000                        Z
# 1917          USGS-10109000                        Z
#
#                     observing_procedure   value unit_of_measure  \
# 0                           Unspecified   17.00          ft^3/s
# 1                                  None    0.94              ft
# 2                           Unspecified   12.50          ft^3/s
# 3                                  None    0.88              ft
# 4                                  None    1.80              ft
# ...                                 ...     ...             ...
# 1913                               None    3.11              ft
# 1914  Acoustic Doppler Current Profiler  354.00          ft^3/s
# 1915                               None    3.38              ft
# 1916                               None    3.28              ft
# 1917  Acoustic Doppler Current Profiler  321.00          ft^3/s
#
#                           time qualifier vertical_datum approval_status  \
# 0    1951-09-06 16:40:00+00:00      None           None        Approved
# 1    1951-09-06 16:40:00+00:00      None           None        Approved
# 2    1951-12-13 19:10:00+00:00      None           None        Approved
# 3    1951-12-13 19:10:00+00:00      None           None        Approved
# 4    1952-04-23 17:25:00+00:00      None           None        Approved
# ...                        ...       ...            ...             ...
# 1913 2026-04-20 16:31:59+00:00      None           None        Approved
# 1914 2026-05-12 20:07:07+00:00      None           None        Approved
# 1915 2026-05-12 20:07:07+00:00      None           None        Approved
# 1916 2026-05-26 23:39:33+00:00      None           None        Approved
# 1917 2026-05-26 23:39:33+00:00      None           None        Approved
#
#      measuring_agency                    last_modified control_condition  \
# 0                USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 1                USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 2                USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 3                USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 4                USGS 2026-06-03 22:25:57.846799+00:00             Clear
# ...               ...                              ...               ...
# 1913             USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 1914             USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 1915             USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 1916             USGS 2026-06-03 22:25:57.846799+00:00             Clear
# 1917             USGS 2026-06-03 22:25:57.846799+00:00             Clear
#
#      measurement_rated                  field_measurement_id
# 0            Excellent  171d94e4-8989-4948-9ebd-42037d03e464
# 1            Excellent  a6764889-4d58-4f83-8e20-d6fde4a5e4e5
# 2          Unspecified  28b847e8-45ac-4643-a4ff-55931b008de4
# 3          Unspecified  891e4d38-b26b-4bd9-a664-8446c916f6b4
# 4                 Good  8803ac0a-5a2e-4538-ac50-8a23b3867e42
# ...                ...                                   ...
# 1913              Good  54242802-9af6-41bb-9959-967334b06e20
# 1914              Fair  d9997123-e13c-4281-8578-8e5b012d3461
# 1915              Fair  f27dc6d2-0962-472e-a1e6-eff975dde0f5
# 1916              Good  4f1c3cdd-7012-4420-8389-d56dab84c507
# 1917              Good  d81ddc27-7142-4241-9452-c306700edd13
#
# [1918 rows x 18 columns]

# %% [markdown]
# Show the data types of the columns in the resulting data frame.

# %%
print(measurements1[0].dtypes)
# Out:
# geometry                                   geometry
# field_measurements_series_id                    str
# field_visit_id                                  str
# parameter_code                                  str
# monitoring_location_id                          str
# observing_procedure_code                        str
# observing_procedure                             str
# value                                       float64
# unit_of_measure                                 str
# time                            datetime64[us, UTC]
# qualifier                                    object
# vertical_datum                                  str
# approval_status                                 str
# measuring_agency                                str
# last_modified                   datetime64[us, UTC]
# control_condition                               str
# measurement_rated                               str
# field_measurement_id                            str
# dtype: object

# %% [markdown]
# The other part of the result returned from the `get_field_measurements()` function is a metadata object that contains information about the query that was executed to return the data. For example, you can access the URL that was assembled to retrieve the requested data from the USGS Water Data API.

# %%
print("The query URL used to retrieve the data from the Water Data API was: " + measurements1[1].url)
# Out:
# The query URL used to retrieve the data from the Water Data API was: https://api.waterdata.usgs.gov/ogcapi/v0/collections/field-measurements/items?monitoring_location_id=USGS-10109000&skipGeometry=false&limit=50000

# %% [markdown]
# ### Additional Examples
#
# Example 2: Get all of the field measurements between a start and end date

# %%
measurements2 = waterdata.get_field_measurements(
    monitoring_location_id="USGS-10109000", time="2019-01-01/2019-12-31"
)
print("Retrieved " + str(len(measurements2[0])) + " data values.")
display(measurements2[0])
# Out:
# Retrieving: field-measurements · 1 page · 18 rows
# Retrieved 18 data values.
#                        geometry          field_measurements_series_id  \
# 0   POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 1   POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 2   POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 3   POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 4   POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 5   POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 6   POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 7   POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 8   POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 9   POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 10  POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 11  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 12  POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 13  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 14  POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 15  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
# 16  POINT (-111.78398 41.74355)  7d5b4004-ca7e-46c5-9bde-25d5dde481c8
# 17  POINT (-111.78398 41.74355)  442c040d-8a0f-43e8-b4c7-840b2a60a89a
#
#                           field_visit_id parameter_code  \
# 0   80a47f55-5d75-9c33-e053-0100007fa04d          00065
# 1   80a47f55-5d75-9c33-e053-0100007fa04d          00060
# 2   83ebd5c5-373c-5a52-e053-0100007f5e38          00065
# 3   83ebd5c5-373c-5a52-e053-0100007f5e38          00060
# 4   873f3a85-f698-41b8-e053-0100007fc351          00065
# 5   873f3a85-f698-41b8-e053-0100007fc351          00060
# 6   8b3913bf-9253-4f4f-e053-0100007f3ec4          00060
# 7   8b3913bf-9253-4f4f-e053-0100007f3ec4          00065
# 8   8ef1af85-190d-3d4c-e053-0100007f711a          00065
# 9   8ef1af85-190d-3d4c-e053-0100007f711a          00060
# 10  8ef1af85-190d-3d4c-e053-0100007f711a          00060
# 11  8ef1af85-190d-3d4c-e053-0100007f711a          00065
# 12  92d627a0-a0f4-3689-e053-0100007f10f2          00060
# 13  92d627a0-a0f4-3689-e053-0100007f10f2          00065
# 14  9603d708-a28c-04b1-e053-0100007f2a41          00060
# 15  9603d708-a28c-04b1-e053-0100007f2a41          00065
# 16  92b3d616-e8fb-4f7f-862d-632f6ad1c26b          00060
# 17  92b3d616-e8fb-4f7f-862d-632f6ad1c26b          00065
#
#    monitoring_location_id observing_procedure_code  \
# 0           USGS-10109000                        Z
# 1           USGS-10109000                        Z
# 2           USGS-10109000                        Z
# 3           USGS-10109000                        Z
# 4           USGS-10109000                        Z
# 5           USGS-10109000                        Z
# 6           USGS-10109000                        Z
# 7           USGS-10109000                        Z
# 8           USGS-10109000                        Z
# 9           USGS-10109000                        Z
# 10          USGS-10109000                        Z
# 11          USGS-10109000                        Z
# 12          USGS-10109000                        Z
# 13          USGS-10109000                        Z
# 14          USGS-10109000                        Z
# 15          USGS-10109000                        Z
# 16          USGS-10109000                        Z
# 17          USGS-10109000                        Z
#
#                   observing_procedure   value unit_of_measure  \
# 0                                None    2.43              ft
# 1                         Mid-section   83.80          ft^3/s
# 2                                None    2.46              ft
# 3                         Mid-section   94.20          ft^3/s
# 4                                None    3.29              ft
# 5   Acoustic Doppler Current Profiler  337.00          ft^3/s
# 6                         Mid-section  709.00          ft^3/s
# 7                                None    4.09              ft
# 8                                None    2.84              ft
# 9                         Mid-section  167.00          ft^3/s
# 10                        Mid-section  162.00          ft^3/s
# 11                               None    2.84              ft
# 12                        Mid-section  126.00          ft^3/s
# 13                               None    2.64              ft
# 14                        Mid-section  133.00          ft^3/s
# 15                               None    2.64              ft
# 16                        Mid-section  122.00          ft^3/s
# 17                               None    2.60              ft
#
#                         time qualifier vertical_datum approval_status  \
# 0  2019-01-29 19:57:30+00:00      None           None        Approved
# 1  2019-01-29 19:57:30+00:00      None           None        Approved
# 2  2019-03-11 19:29:30+00:00      None           None        Approved
# 3  2019-03-11 19:29:30+00:00      None           None        Approved
# 4  2019-04-23 21:39:16+00:00      None           None        Approved
# 5  2019-04-23 21:39:16+00:00      None           None        Approved
# 6  2019-06-12 14:02:56+00:00      None           None        Approved
# 7  2019-06-12 14:02:56+00:00      None           None        Approved
# 8  2019-07-30 17:57:17+00:00      None           None        Approved
# 9  2019-07-30 17:57:17+00:00      None           None        Approved
# 10 2019-07-30 18:06:00+00:00      None           None        Approved
# 11 2019-07-30 18:06:00+00:00      None           None        Approved
# 12 2019-09-16 16:59:19+00:00      None           None        Approved
# 13 2019-09-16 16:59:19+00:00      None           None        Approved
# 14 2019-10-28 19:06:42+00:00      None           None        Approved
# 15 2019-10-28 19:06:42+00:00      None           None        Approved
# 16 2019-12-03 20:53:15+00:00      None           None        Approved
# 17 2019-12-03 20:53:15+00:00      None           None        Approved
#
#    measuring_agency                    last_modified   control_condition  \
# 0              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 1              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 2              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 3              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 4              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 5              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 6              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 7              USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 8              USGS 2026-06-03 22:25:57.846799+00:00  Vegetation - Light
# 9              USGS 2026-06-03 22:25:57.846799+00:00  Vegetation - Light
# 10             USGS 2026-06-03 22:25:57.846799+00:00  Vegetation - Light
# 11             USGS 2026-06-03 22:25:57.846799+00:00  Vegetation - Light
# 12             USGS 2026-06-03 22:25:57.846799+00:00  Vegetation - Light
# 13             USGS 2026-06-03 22:25:57.846799+00:00  Vegetation - Light
# 14             USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 15             USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 16             USGS 2026-06-03 22:25:57.846799+00:00               Clear
# 17             USGS 2026-06-03 22:25:57.846799+00:00               Clear
#
#    measurement_rated                  field_measurement_id
# 0               Good  6bdeaecd-a7aa-4be0-bff2-e6c5ef2df404
# 1               Good  ca56f390-44e2-4ac9-a038-f7427f1310f3
# 2               Good  78cb7375-25e4-4ac6-8e9a-c8c1a55844f0
# 3               Good  a498deb9-40a0-4a8e-a5e8-86dce988995d
# 4               Good  631ffc3c-d80c-4704-b126-8729e63c906c
# 5               Good  71cede54-6330-4413-9a10-380cd8f2ee78
# 6               Good  98d24fbd-2c9f-4f1a-a3be-571d27e9a441
# 7               Good  ef5d6df8-8081-4e39-930e-40cc190aa9b6
# 8               Good  2d379146-bd65-4a8c-a868-665a10c933be
# 9               Good  41ef994d-6896-4fd9-b31c-d7284e4e32eb
# 10              Good  44659028-4656-4d92-a89a-aa44e2f0ea78
# 11              Good  4f7bb602-4112-4249-9ccf-5dc49e52428f
# 12              Good  17b797f6-7135-4c19-a1a1-78272482ba38
# 13              Good  e5b5f085-a98e-489a-87e1-36024bb9dca6
# 14              Good  5fab5973-e8eb-4ef9-a65c-31d2c5898198
# 15              Good  a93eecf4-982b-4c7e-9ad0-22278bb9030f
# 16              Good  329fff59-5f9d-4567-afc8-96dbbde2e885
# 17              Good  6f5f04d1-5473-4e44-bba3-3c90c8e6c591

# %% [markdown]
# Example 3: Get all of the field measurements for multiple monitoring locations

# %%
measurements3 = waterdata.get_field_measurements(monitoring_location_id=["USGS-01594440", "USGS-040851325"])
print("Retrieved " + str(len(measurements3[0])) + " data values.")
display(measurements3[0])
# Out:
# Retrieving: field-measurements · 1 page · 976 rows
# Retrieved 976 data values.
#                        geometry          field_measurements_series_id  \
# 0    POINT (-76.69369 38.95592)  61b6cb68-e338-4dfd-9618-d64e9bdc64be
# 1    POINT (-76.69369 38.95592)  c296b625-80d8-4ee8-a14b-f9bdaf158468
# 2    POINT (-76.69369 38.95592)  61b6cb68-e338-4dfd-9618-d64e9bdc64be
# 3    POINT (-76.69369 38.95592)  c296b625-80d8-4ee8-a14b-f9bdaf158468
# 4    POINT (-76.69369 38.95592)  61b6cb68-e338-4dfd-9618-d64e9bdc64be
# ..                          ...                                   ...
# 971  POINT (-76.69369 38.95592)  61b6cb68-e338-4dfd-9618-d64e9bdc64be
# 972  POINT (-76.69369 38.95592)  c296b625-80d8-4ee8-a14b-f9bdaf158468
# 973  POINT (-76.69369 38.95592)  61b6cb68-e338-4dfd-9618-d64e9bdc64be
# 974  POINT (-76.69369 38.95592)  c296b625-80d8-4ee8-a14b-f9bdaf158468
# 975  POINT (-76.69369 38.95592)  61b6cb68-e338-4dfd-9618-d64e9bdc64be
#
#                            field_visit_id parameter_code  \
# 0    53fb2a20-7b79-4148-e053-0100007f46df          00065
# 1    53fb2a20-7b79-4148-e053-0100007f46df          00060
# 2    53fb2518-fafa-3f15-e053-0100007fbbce          00065
# 3    53fb2518-fafa-3f15-e053-0100007fbbce          00060
# 4    53fb2a2a-6d26-3f11-e053-0100007f0ef5          00065
# ..                                    ...            ...
# 971  25d5d229-9953-4096-8c53-7f62965975a8          00065
# 972  1cef619c-e54c-4d50-8f72-8a7067de4e15          00060
# 973  1cef619c-e54c-4d50-8f72-8a7067de4e15          00065
# 974  53cd995f-745d-4342-bbb8-2c3a294fc56a          00060
# 975  53cd995f-745d-4342-bbb8-2c3a294fc56a          00065
#
#     monitoring_location_id observing_procedure_code  \
# 0            USGS-01594440                        Z
# 1            USGS-01594440                        Z
# 2            USGS-01594440                        Z
# 3            USGS-01594440                        Z
# 4            USGS-01594440                        Z
# ..                     ...                      ...
# 971          USGS-01594440                        Z
# 972          USGS-01594440                        Z
# 973          USGS-01594440                        Z
# 974          USGS-01594440                        Z
# 975          USGS-01594440                        Z
#
#                    observing_procedure   value unit_of_measure  \
# 0                                 None    3.11              ft
# 1                          Unspecified  152.00          ft^3/s
# 2                                 None    2.76              ft
# 3                          Unspecified  127.00          ft^3/s
# 4                                 None    4.26              ft
# ..                                 ...     ...             ...
# 971                               None    4.36              ft
# 972  Acoustic Doppler Current Profiler  219.00          ft^3/s
# 973                               None    4.99              ft
# 974  Acoustic Doppler Current Profiler  121.00          ft^3/s
# 975                               None    4.24              ft
#
#                          time qualifier vertical_datum approval_status  \
# 0   1955-04-07 19:05:00+00:00      None           None        Approved
# 1   1955-04-07 19:05:00+00:00      None           None        Approved
# 2   1955-05-04 21:05:00+00:00      None           None        Approved
# 3   1955-05-04 21:05:00+00:00      None           None        Approved
# 4   1955-06-10 13:35:00+00:00      None           None        Approved
# ..                        ...       ...            ...             ...
# 971 2026-01-07 16:40:27+00:00      None           None        Approved
# 972 2026-03-23 15:23:18+00:00      None           None     Provisional
# 973 2026-03-23 15:23:18+00:00      None           None     Provisional
# 974 2026-05-20 15:33:18+00:00      None           None     Provisional
# 975 2026-05-20 15:33:18+00:00      None           None     Provisional
#
#     measuring_agency                    last_modified control_condition  \
# 0               USGS 2026-05-22 11:05:41.715713+00:00             Clear
# 1               USGS 2026-05-22 11:05:41.715713+00:00             Clear
# 2               USGS 2026-05-22 11:05:41.715713+00:00             Clear
# 3               USGS 2026-05-22 11:05:41.715713+00:00             Clear
# 4               USGS 2026-05-22 11:05:41.715713+00:00             Clear
# ..               ...                              ...               ...
# 971             USGS 2026-05-22 11:05:41.715713+00:00             Clear
# 972             USGS 2026-05-22 11:05:41.715713+00:00    Debris - Light
# 973             USGS 2026-05-22 11:05:41.715713+00:00    Debris - Light
# 974             USGS 2026-05-22 11:05:41.715713+00:00             Clear
# 975             USGS 2026-05-22 11:05:41.715713+00:00             Clear
#
#     measurement_rated                  field_measurement_id
# 0                Good  4b1b4d58-f507-48e9-a4ba-77f6e722d8bb
# 1                Good  845573db-b7cb-4db6-b0fb-1ea3667d89d8
# 2                Fair  62218c9c-82a5-46c2-91e1-443fb88cd76b
# 3                Fair  b752e796-671e-4791-bd57-1bf8a2e8d27b
# 4                Good  d6f4cbc0-bd8f-4a3a-8129-3adc73f99e7c
# ..                ...                                   ...
# 971              Fair  d771ccbd-3df7-4abb-905a-f16925c61879
# 972              Fair  681c20fe-eb51-4ad1-9990-62494ec0e43a
# 973              Fair  f7ef53bd-e01c-4705-8d39-95a1e6eeffde
# 974              Fair  0411981d-bf8f-4c57-9aea-9b9e537ebbee
# 975              Fair  74e911ed-5c5f-4441-8124-19c27af210c3
#
# [976 rows x 18 columns]
