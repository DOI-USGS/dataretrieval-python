# %% [markdown]
# # USGS dataretrieval Python Package `what_sites()` Examples
#
# This notebook provides examples of using the Python dataretrieval package to search NWIS for sites within a region with specific data. The dataretrieval package provides a collection of functions to get data from the USGS National Water Information System (NWIS) and other online sources of hydrology and water quality data, including the United States Environmental Protection Agency (USEPA).

# %% [markdown]
# ### Install the Package
#
# Use the following code to install the package if it doesn't exist already within your Jupyter Python environment.

# %%
# !pip install dataretrieval
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dataretrieval in /home/runner/.local/lib/python3.12/site-packages (0.1.dev1+g50466c8c4)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from dataretrieval) (2.31.0)
# Requirement already satisfied: pandas==2.* in /home/runner/.local/lib/python3.12/site-packages (from dataretrieval) (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/runner/.local/lib/python3.12/site-packages (from pandas==2.*->dataretrieval) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from pandas==2.*->dataretrieval) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas==2.*->dataretrieval) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/runner/.local/lib/python3.12/site-packages (from pandas==2.*->dataretrieval) (2025.2)

# %% [markdown]
# Load the package so you can use it along with other packages used in this notebook.

# %%
from dataretrieval import nwis
from IPython.display import display

# %% [markdown]
# ### Basic Usage
#
# The dataretrieval package has several functions that allow you to retrieve data from different web services. This examples uses the `what_sites()` function to search NWIS for sites within a region with specific data. The function has several arguments, depending on the result you want to retrieve.
#
# Note: Must specify one major argument.
#
# #### Major Arguments (Additional arguments, if supplied, will be used as query parameters)
#
# * **sites** (string or list): A list of site numbers. Sites may be prefixed with an optional agency code followed by a colon.
# * **stateCd** (string): U.S. postal service (2-digit) state code. Only 1 state can be specified per request.
# * **huc** (string or list): A list of hydrologic unit codes (HUC) or aggregated watersheds. Only 1 major HUC can be specified per request, or up to 10 minor HUCs. A major HUC has two digits.
# * **bBox** (list): A contiguous range of decimal latitude and longitude, starting with the west longitude, then the south latitude, then the east longitude, and then the north latitude with each value separated by a comma. The product of the range of latitude range and longitude cannot exceed 25 degrees. Whole or decimal degrees must be specified, up to six digits of precision. Minutes and seconds are not allowed.
# * **countyCd** (string or list): A list of county numbers, in a 5 digit numeric format. The first two digits of a county's code are the FIPS State Code. (url: https://help.waterdata.usgs.gov/code/county_query?fmt=html)
#
# #### Minor Arguments
#
# * **startDt** (string): Selects sites based on whether data was collected at a point in time beginning after startDt (start date). Dates must be in ISO-8601 Calendar Date format (for example: 1990-01-01).
# * **endDt** (string)
# * **period** (string): Selects sites based on whether or not they were active between now and a time in the past. For example, period=P10W will select sites active in the last ten weeks.
# * **modifiedSince** (string): Returns only sites where site attributes or period of record data have changed during the request period.
# * **parameterCd** (string or list): Returns only site data for those sites containing the requested USGS parameter codes.
# * **siteType** (string or list): Restricts sites to those having one or more major and/or minor site types, such as stream, spring or well. For a list of all valid site types see https://help.waterdata.usgs.gov/site_tp_cd. For example, siteType='ST' returns streams only.
#
# #### Formatting Parameters
#
# * **siteOutput** (string 'basic' or 'expanded'): Indicates the richness of metadata you want for site attributes. Note that for visually oriented formats like Google Map format, this argument has no meaning. Note: for performance reasons, siteOutput='expanded' cannot be used if seriesCatalogOutput=true or with any values for outputDataTypeCd.
# * **seriesCatalogOutput** (boolean): A switch that provides detailed period of record information for certain output formats. The period of record indicates date ranges for a certain kind of information about a site, for example the start and end dates for a site's daily mean streamflow.
#
# For additional parameter options see https://waterservices.usgs.gov/docs/site-service/site-service-details

# %% [markdown]
# #### Example 1: Retrieve information about sites in Ohio where phosphorus data was collected

# %%
siteListPhos = nwis.what_sites(stateCd="OH", parameterCd="00665")

# %% [markdown]
# ### Interpreting the Result
#
# The result of calling the `what_sites()` function is an object that contains a Pandas data frame object and an associated metadata object. The Pandas data frame contains the requestes site inventory data.
#
# Once you've got the data frame, there's several useful things you can do to explore the data.

# %%
# Display the data frame as a table
display(siteListPhos[0])
# Out:
#      agency_cd          site_no  \
# 0         USGS         03086500
# 1         USGS         03089500
# 2         USGS         03090500
# 3         USGS         03091500
# 4         USGS         03092000
# ...        ...              ...
# 1275      USGS  414144084242500
# 1276      USGS  414150084331000
# 1277      USGS  414214083151000
# 1278      USGS  414233083595500
# 1279      USGS  414937083112500
#
#                                             station_nm site_tp_cd  dec_lat_va  \
# 0                        Mahoning River at Alliance OH         ST   40.932836
# 1                     Mill Creek near Berlin Center OH         ST   41.000336
# 2     Mahoning River bl Berlin Dam nr Berlin Center OH         ST   41.048391
# 3                       Mahoning River at Pricetown OH         ST   41.131446
# 4                         Kale Creek near Pricetown OH         ST   41.139779
# ...                                                ...        ...         ...
# 1275                                         WM-103 OH         GW   41.686439
# 1276                                      WM-87-S14 OH         GW   41.697272
# 1277             Lake Erie at site WE12 near Toledo OH         LK         NaN
# 1278        Little Bear Creek at HWY 120 nr Seward, OH     ST-DCH   41.709167
# 1279              Lake Erie at site WE4 near Toledo OH         LK         NaN
#
#       dec_long_va coord_acy_cd dec_coord_datum_cd   alt_va  alt_acy_va  \
# 0      -81.094541            S              NAD83  1034.79        0.10
# 1      -80.968424            S              NAD83  1032.90        0.01
# 2      -81.001203            S              NAD83   957.72        0.01
# 3      -80.971202            S              NAD83   904.77        0.10
# 4      -80.995092            S              NAD83   914.70        0.01
# ...           ...          ...                ...      ...         ...
# 1275   -84.406893            S              NAD83   850.00       10.00
# 1276   -84.552728            S              NAD83   895.00       10.00
# 1277          NaN            S                NaN      NaN         NaN
# 1278   -83.998611            S              NAD83      NaN         NaN
# 1279          NaN            S                NaN      NaN         NaN
#
#      alt_datum_cd     huc_cd                    geometry
# 0          NAVD88  5030103.0  POINT (-81.09454 40.93284)
# 1          NGVD29  5030103.0  POINT (-80.96842 41.00034)
# 2          NAVD88  5030103.0   POINT (-81.0012 41.04839)
# 3          NAVD88  5030103.0   POINT (-80.9712 41.13145)
# 4         COE1912  5030103.0  POINT (-80.99509 41.13978)
# ...           ...        ...                         ...
# 1275       NGVD29  4100006.0  POINT (-84.40689 41.68644)
# 1276       NGVD29  4100003.0  POINT (-84.55273 41.69727)
# 1277          NaN  4120200.0             POINT (NaN NaN)
# 1278          NaN  4100002.0  POINT (-83.99861 41.70917)
# 1279          NaN  4120200.0             POINT (NaN NaN)
#
# [1280 rows x 13 columns]

# %% [markdown]
# The other part of the result returned from the `what_sites()` function is a metadata object that contains information about the query that was executed to return the data. For example, you can access the URL that was assembled to retrieve the requested data from the USGS web service. The USGS web service responses contain a descriptive header that defines and can be helpful in interpreting the contents of the response.

# %%
print('The query URL used to retrieve the data from NWIS was: ' + siteListPhos[1].url)
# Out:
# The query URL used to retrieve the data from NWIS was: https://waterservices.usgs.gov/nwis/site?stateCd=OH&parameterCd=00665&format=rdb

# %% [markdown]
# ### Additional Examples
#
# #### Example 2: Retrieve site information for a single site

# %%
oneSite = nwis.what_sites(sites='05114000')
display(oneSite[0])
# Out:
#   agency_cd   site_no                      station_nm site_tp_cd  dec_lat_va  \
# 0      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST   48.989957
#
#    dec_long_va coord_acy_cd dec_coord_datum_cd  alt_va  alt_acy_va  \
# 0  -101.958335            F              NAD83  1605.0        0.19
#
#   alt_datum_cd   huc_cd                     geometry
# 0       NAVD88  9010008  POINT (-101.95833 48.98996)

# %% [markdown]
# #### Example 3: Retrieve site information for a single site and show the result with expanded output

# %%
oneSite = nwis.what_sites(sites='05114000', siteOutput='expanded')
display(oneSite[0])
# Out:
#   agency_cd   site_no                      station_nm site_tp_cd  lat_va  \
# 0      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST  485924
#
#    long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0  1015728   48.989957  -101.958335             M            F  ...
#
#   reliability_cd gw_file_cd  nat_aqfr_cd  aqfr_cd  aqfr_type_cd well_depth_va  \
# 0            NaN   NNNNNNNN          NaN      NaN           NaN           NaN
#
#   hole_depth_va depth_src_cd  project_no                     geometry
# 0           NaN          NaN         NaN  POINT (-101.95833 48.98996)
#
# [1 rows x 43 columns]

# %% [markdown]
# #### Example 4: Retrieve site information for sites in Utah with daily values data falling within a specified date range

# %%
UTsites = nwis.what_sites(stateCd='UT', outputDataTypeCd='dv', startDT='1971-07-01', endDT='2021-07-28')
display(UTsites[0])
# Out:
#      agency_cd          site_no                                 station_nm  \
# 0         USGS         09163675  COTTONWOOD WASH AT I-70, NEAR CISCO, UTAH
# 1         USGS         09180000               DOLORES RIVER NEAR CISCO, UT
# 2         USGS         09180000               DOLORES RIVER NEAR CISCO, UT
# 3         USGS         09180000               DOLORES RIVER NEAR CISCO, UT
# 4         USGS         09180000               DOLORES RIVER NEAR CISCO, UT
# ...        ...              ...                                        ...
# 1237      USGS  414411112543701                          (B-12- 9)30cda- 1
# 1238      USGS  414500112000000      COM FLOW BEAR AREA GSL INFLOW GROUP 1
# 1239      USGS  414500112000100      COM FLOW BEAR AREA GSL INFLOW GROUP 2
# 1240      USGS  414500112000200      COM FLOW BEAR AREA GSL INFLOW GROUP 3
# 1241      USGS  415703112514501                          (B-14- 9) 9add- 1
#
#      site_tp_cd  dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 0            ST   39.081652  -109.217615            F              NAD83
# 1            ST   38.797208  -109.195114            F              NAD83
# 2            ST   38.797208  -109.195114            F              NAD83
# 3            ST   38.797208  -109.195114            F              NAD83
# 4            ST   38.797208  -109.195114            F              NAD83
# ...         ...         ...          ...          ...                ...
# 1237         GW   41.736312  -112.911094            S              NAD83
# 1238         ST   41.749928  -112.000782            F              NAD83
# 1239         ST   41.749928  -112.001059            F              NAD83
# 1240         ST   41.749928  -112.001337            F              NAD83
# 1241         GW   41.960106  -112.863444            1              NAD83
#
#        alt_va  alt_acy_va  ...   ts_id  loc_web_ds medium_grp_cd parm_grp_cd  \
# 0         NaN         NaN  ...  142731         NaN           wat         NaN
# 1     4168.32        0.11  ...  241055         NaN           wat         NaN
# 2     4168.32        0.11  ...  241056         NaN           wat         NaN
# 3     4168.32        0.11  ...  142732         NaN           wat         NaN
# 4     4168.32        0.11  ...  142733         NaN           wat         NaN
# ...       ...         ...  ...     ...         ...           ...         ...
# 1237  4239.00        0.50  ...  144019         NaN           wat         NaN
# 1238      NaN         NaN  ...  144020         NaN           wat         NaN
# 1239      NaN         NaN  ...  144021         NaN           wat         NaN
# 1240      NaN         NaN  ...  144022         NaN           wat         NaN
# 1241  4387.88        0.10  ...  144023         NaN           wat         NaN
#
#        srs_id  access_cd  begin_date    end_date  count_nu  \
# 0     1645423          0  1983-04-13  1986-09-30      1267
# 1     1645597          0  2006-07-18  2025-12-04      7008
# 2     1645597          0  2006-07-19  2025-12-04      6991
# 3     1645597          0  2006-07-19  2025-12-03      6984
# 4     1645597          0  1949-05-01  2004-08-17     13002
# ...       ...        ...         ...         ...       ...
# 1237  1642008          0  1975-10-05  2025-11-17      9517
# 1238  1645423          0  1960-10-01  1982-09-29      7303
# 1239  1645423          0  1960-10-01  1980-09-29      6207
# 1240  1645423          0  1960-10-01  1980-09-29      6573
# 1241  1642008          0  1981-07-21  2025-08-12     15104
#
#                          geometry
# 0     POINT (-109.21762 39.08165)
# 1     POINT (-109.19511 38.79721)
# 2     POINT (-109.19511 38.79721)
# 3     POINT (-109.19511 38.79721)
# 4     POINT (-109.19511 38.79721)
# ...                           ...
# 1237  POINT (-112.91109 41.73631)
# 1238  POINT (-112.00078 41.74993)
# 1239  POINT (-112.00106 41.74993)
# 1240  POINT (-112.00134 41.74993)
# 1241  POINT (-112.86344 41.96011)
#
# [1242 rows x 25 columns]

# %% [markdown]
# #### Example 5: Retrieve site information for a single site and show the series catalog output
#
# The series catalog output is a list of the parameters that have been collected at that site

# %%
oneSite = nwis.what_sites(sites='05114000', seriesCatalogOutput='true')
display(oneSite[0])
# Out:
#     agency_cd   site_no                      station_nm site_tp_cd  \
# 0        USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 1        USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 2        USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 3        USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 4        USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# ..        ...       ...                             ...        ...
# 402      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 403      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 404      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 405      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
# 406      USGS  05114000  SOURIS RIVER NEAR SHERWOOD, ND         ST
#
#      dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd  alt_va  \
# 0     48.989957  -101.958335            F              NAD83  1605.0
# 1     48.989957  -101.958335            F              NAD83  1605.0
# 2     48.989957  -101.958335            F              NAD83  1605.0
# 3     48.989957  -101.958335            F              NAD83  1605.0
# 4     48.989957  -101.958335            F              NAD83  1605.0
# ..          ...          ...          ...                ...     ...
# 402   48.989957  -101.958335            F              NAD83  1605.0
# 403   48.989957  -101.958335            F              NAD83  1605.0
# 404   48.989957  -101.958335            F              NAD83  1605.0
# 405   48.989957  -101.958335            F              NAD83  1605.0
# 406   48.989957  -101.958335            F              NAD83  1605.0
#
#      alt_acy_va  ...   ts_id  loc_web_ds medium_grp_cd parm_grp_cd    srs_id  \
# 0          0.19  ...       0         NaN           wat         NaN         0
# 1          0.19  ...   91355         NaN           wat         NaN   1645597
# 2          0.19  ...   91356         NaN           wat         NaN   1645597
# 3          0.19  ...   91357         NaN           wat         NaN   1645597
# 4          0.19  ...   91358         NaN           wat         NaN   1645597
# ..          ...  ...     ...         ...           ...         ...       ...
# 402        0.19  ...   92591         NaN           wat         NaN   1645423
# 403        0.19  ...   92592         NaN           wat         NaN  17164583
# 404        0.19  ...  249682         NaN           wat         NaN   1646694
# 405        0.19  ...  249681         NaN           wat         NaN   1736457
# 406        0.19  ...  317832         NaN           wat         NaN   1642503
#
#      access_cd  begin_date    end_date count_nu                     geometry
# 0            0        2006        2025       20  POINT (-101.95833 48.98996)
# 1            0  1983-08-11  2024-10-31     6094  POINT (-101.95833 48.98996)
# 2            0  1983-08-11  2024-10-31     6094  POINT (-101.95833 48.98996)
# 3            0  1983-08-11  2024-10-31     6094  POINT (-101.95833 48.98996)
# 4            0  1974-10-17  1981-09-02     1937  POINT (-101.95833 48.98996)
# ..         ...         ...         ...      ...                          ...
# 402          0  1994-10-01  2025-12-04    11387  POINT (-101.95833 48.98996)
# 403          0  2007-10-01  2025-12-04     6639  POINT (-101.95833 48.98996)
# 404          0  2019-05-15  2023-10-10     1609  POINT (-101.95833 48.98996)
# 405          0  2019-05-15  2023-10-10     1609  POINT (-101.95833 48.98996)
# 406          0  2025-01-01  2025-12-04      337  POINT (-101.95833 48.98996)
#
# [407 rows x 25 columns]
