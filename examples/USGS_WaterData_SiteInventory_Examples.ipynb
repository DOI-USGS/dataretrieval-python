# %% [markdown]
# # USGS dataretrieval Python Package `get_monitoring_locations()` Examples
#
# This notebook provides examples of using the Python dataretrieval package to search for monitoring locations within a region or with specific characteristics. The dataretrieval package provides a collection of functions to get data from the USGS Water Data API and other online sources of hydrology and water quality data, including the United States Environmental Protection Agency (USEPA).

# %% [markdown]
# ### Install the Package
#
# Use the following code to install the package if it doesn't exist already within your Jupyter Python environment.

# %%
# !pip install dataretrieval
# Out:
# Requirement already satisfied: dataretrieval in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (0.1.dev1+g18090d40f)
# Requirement already satisfied: httpx in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from dataretrieval) (0.28.1)
# Requirement already satisfied: pandas<4.0.0,>=2.0.0 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from dataretrieval) (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from pandas<4.0.0,>=2.0.0->dataretrieval) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from pandas<4.0.0,>=2.0.0->dataretrieval) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<4.0.0,>=2.0.0->dataretrieval) (1.17.0)
# Requirement already satisfied: anyio in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (4.13.0)
# Requirement already satisfied: certifi in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (1.0.9)
# Requirement already satisfied: idna in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpx->dataretrieval) (3.17)
# Requirement already satisfied: h11>=0.16 in /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/site-packages (from httpcore==1.*->httpx->dataretrieval) (0.16.0)

# %% [markdown]
# Load the package so you can use it along with other packages used in this notebook.

# %%
from IPython.display import display

import dataretrieval.waterdata as waterdata

# %% [markdown]
# ### Basic Usage
#
# The dataretrieval package has several functions that allow you to retrieve data from the USGS Water Data API. This example uses the `get_monitoring_locations()` function to search for monitoring locations within a region or with specific characteristics. The function has many optional arguments that act as filters on the query; supply the ones that match the locations you want to retrieve.
#
# #### Commonly Used Arguments
#
# * **monitoring_location_id** (string or iterable of strings): A unique identifier for a single monitoring location, formed by joining the agency code (e.g. `USGS`) and the location's ID number with a hyphen (e.g. `USGS-05114000`).
# * **state_name** (string or iterable of strings): The full name of the state or state equivalent in which the monitoring location is located (e.g. `"Ohio"`, `"Utah"`). Note that this is the spelled-out state name, not a two-letter postal abbreviation.
# * **county_name** (string or iterable of strings): The name of the county (or county equivalent) in which the monitoring location is located.
# * **site_type_code** (string or iterable of strings): A code describing the hydrologic setting of the monitoring location (e.g. stream, spring, or well).
# * **site_type** (string or iterable of strings): A text description of the hydrologic setting of the monitoring location.
# * **hydrologic_unit_code** (string or iterable of strings): A two- to eight-digit hydrologic unit code (HUC) identifying the region, sub-region, accounting unit, or cataloging unit of interest.
# * **bbox** (list of numbers): A bounding box given as `[xmin, ymin, xmax, ymax]` (western-most longitude, southern-most latitude, eastern-most longitude, northern-most latitude). Only locations whose geometry intersects the box are returned.
#
# #### Formatting Arguments
#
# * **properties** (string or iterable of strings): The subset of columns to return from the query (for example `id`, `state_name`, `site_type_code`). When omitted, all available columns are returned.
# * **skip_geometry** (boolean): When `True`, the response geometries are skipped and the result is a plain `pandas.DataFrame` with no spatial information. When `False` (the default), the result carries a `geometry` column.
# * **limit** (numeric): Controls how many of the selected features are returned per page (maximum 50000).
#
# For the full list of arguments see the `get_monitoring_locations()` docstring and the USGS Water Data API documentation.

# %% [markdown]
# #### Example 1: Retrieve all monitoring locations in Ohio

# %%
siteListPhos = waterdata.get_monitoring_locations(state_name="Ohio")
# Out:
# Retrieving: monitoring-locations · 1 page · 16,074 rows
# No API key detected — register for higher rate limits at https://api.waterdata.usgs.gov/signup/

# %% [markdown]
# ### Interpreting the Result
#
# Calling `get_monitoring_locations()` returns a tuple of two objects: a pandas data frame of the requested monitoring location records and an associated metadata object. The data frame has one row per monitoring location and one column per requested property; unless `skip_geometry=True` was passed, it also carries a `geometry` column describing each location's position.
#
# Once you have the data frame, there are several useful things you can do to explore the data.

# %%
# Display the data frame as a table
display(siteListPhos[0])
# Out:
#       monitoring_location_id                    geometry agency_code  \
# 0      OH004-404325082475900  POINT (-82.79963 40.72367)       OH004
# 1      OH015-383638082103300  POINT (-82.17601 38.61071)       OH015
# 2      OH015-385702083013400  POINT (-83.02597 38.95062)       OH015
# 3      OH015-385932083412400  POINT (-83.68992 38.99229)       OH015
# 4      OH015-390359083015100  POINT (-83.03073 39.06646)       OH015
# ...                      ...                         ...         ...
# 16069   USGS-939204016900547  POINT (-81.77917 40.96528)        USGS
# 16070   USGS-939204016901922   POINT (-81.9725 40.80083)        USGS
# 16071   USGS-939204016901945     POINT (-81.95 40.77083)        USGS
# 16072   USGS-939204016902088  POINT (-81.97333 40.79944)        USGS
# 16073   USGS-939204017303335  POINT (-83.60417 41.38444)        USGS
#
#                                 agency_name monitoring_location_number  \
# 0      Ohio Environmental Protection Agency            404325082475900
# 1      Ohio Department of Natural Resources            383638082103300
# 2      Ohio Department of Natural Resources            385702083013400
# 3      Ohio Department of Natural Resources            385932083412400
# 4      Ohio Department of Natural Resources            390359083015100
# ...                                     ...                        ...
# 16069                U.S. Geological Survey            939204016900547
# 16070                U.S. Geological Survey            939204016901922
# 16071                U.S. Geological Survey            939204016901945
# 16072                U.S. Geological Survey            939204016902088
# 16073                U.S. Geological Survey            939204017303335
#
#               monitoring_location_name district_code country_code  \
# 0              GALION WATER DEPARTMENT            39           US
# 1                               G-2 OH            39           US
# 2                              SC-2 OH            39           US
# 3                             BR-20 OH            39           US
# 4                              PI-2 OH            39           US
# ...                                ...           ...          ...
# 16069              MORTON SALT-RITTMAN            39           US
# 16070               BOSCH REXROTH CORP            39           US
# 16071       TIMKEN-WOOSTER STEEL PLANT            39           US
# 16072          FRITO LAY-WOOSTER PLANT            39           US
# 16073  VEHTEK SYSTEMS INC - DEWATERING            39           US
#
#                    country_name state_code  ... construction_date  \
# 0      United States of America         39  ...               NaT
# 1      United States of America         39  ...        1972-01-01
# 2      United States of America         39  ...        2019-10-11
# 3      United States of America         39  ...        1992-12-10
# 4      United States of America         39  ...        1967-01-01
# ...                         ...        ...  ...               ...
# 16069  United States of America         39  ...               NaT
# 16070  United States of America         39  ...               NaT
# 16071  United States of America         39  ...               NaT
# 16072  United States of America         39  ...               NaT
# 16073  United States of America         39  ...               NaT
#
#       aquifer_code national_aquifer_code aquifer_type_code  \
# 0              NaN                   NaN               NaN
# 1          111TRRC            N100ALLUVL                 U
# 2          112OTSH            N100GLCIAL               NaN
# 3          357BFLD            N400SLRDVN                 C
# 4          112OTSH            N100GLCIAL                 U
# ...            ...                   ...               ...
# 16069          NaN                   NaN               NaN
# 16070          NaN                   NaN               NaN
# 16071          NaN                   NaN               NaN
# 16072          NaN                   NaN               NaN
# 16073          NaN                   NaN               NaN
#
#       well_constructed_depth hole_constructed_depth depth_source_code  \
# 0                        NaN                    NaN               NaN
# 1                       65.0                   65.0               NaN
# 2                       85.0                   85.0                 D
# 3                       40.0                   40.0                 A
# 4                       63.0                   63.0               NaN
# ...                      ...                    ...               ...
# 16069                    NaN                    NaN               NaN
# 16070                    NaN                    NaN               NaN
# 16071                    NaN                    NaN               NaN
# 16072                    NaN                    NaN               NaN
# 16073                    NaN                    NaN               NaN
#
#       revision_note  revision_created  revision_modified
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
# ...             ...               ...                ...
# 16069           NaN               NaN                NaN
# 16070           NaN               NaN                NaN
# 16071           NaN               NaN                NaN
# 16072           NaN               NaN                NaN
# 16073           NaN               NaN                NaN
#
# [16074 rows x 44 columns]

# %% [markdown]
# The other part of the result returned from the `get_monitoring_locations()` function is a metadata object that contains information about the query that was executed to return the data. For example, you can access the URL that was assembled to retrieve the requested data from the USGS Water Data API.

# %%
print("The query URL used to retrieve the data from the Water Data API was: " + siteListPhos[1].url)
# Out:
# The query URL used to retrieve the data from the Water Data API was: https://api.waterdata.usgs.gov/ogcapi/v0/collections/monitoring-locations/items?state_name=Ohio&skipGeometry=false&limit=50000

# %% [markdown]
# ### Additional Examples
#
# #### Example 2: Retrieve information for a single monitoring location

# %%
oneSite = waterdata.get_monitoring_locations(monitoring_location_id="USGS-05114000")
display(oneSite[0])
# Out:
# Retrieving: monitoring-locations · 1 page · 1 rows
#   monitoring_location_id                     geometry agency_code  \
# 0          USGS-05114000  POINT (-101.95833 48.98996)        USGS
#
#               agency_name monitoring_location_number  \
# 0  U.S. Geological Survey                   05114000
#
#          monitoring_location_name district_code country_code  \
# 0  SOURIS RIVER NEAR SHERWOOD, ND            38           US
#
#                country_name state_code  ... construction_date aquifer_code  \
# 0  United States of America         38  ...               NaT         None
#
#   national_aquifer_code aquifer_type_code well_constructed_depth  \
# 0                  None              None                    NaN
#
#   hole_constructed_depth depth_source_code  \
# 0                    NaN              None
#
#                                     revision_note           revision_created  \
# 0  WSP 1308: 1934, 1945. WSP 2113: Drainage area.  2017-11-13T06:00:00+00:00
#
#    revision_modified
# 0               None
#
# [1 rows x 44 columns]

# %% [markdown]
# #### Example 3: Retrieve information for a single monitoring location

# %%
oneSite = waterdata.get_monitoring_locations(monitoring_location_id="USGS-05114000")
display(oneSite[0])
# Out:
# Retrieving: monitoring-locations · 1 page · 1 rows
#   monitoring_location_id                     geometry agency_code  \
# 0          USGS-05114000  POINT (-101.95833 48.98996)        USGS
#
#               agency_name monitoring_location_number  \
# 0  U.S. Geological Survey                   05114000
#
#          monitoring_location_name district_code country_code  \
# 0  SOURIS RIVER NEAR SHERWOOD, ND            38           US
#
#                country_name state_code  ... construction_date aquifer_code  \
# 0  United States of America         38  ...               NaT         None
#
#   national_aquifer_code aquifer_type_code well_constructed_depth  \
# 0                  None              None                    NaN
#
#   hole_constructed_depth depth_source_code  \
# 0                    NaN              None
#
#                                     revision_note           revision_created  \
# 0  WSP 1308: 1934, 1945. WSP 2113: Drainage area.  2017-11-13T06:00:00+00:00
#
#    revision_modified
# 0               None
#
# [1 rows x 44 columns]

# %% [markdown]
# #### Example 4: Retrieve information for monitoring locations in Utah

# %%
UTsites = waterdata.get_monitoring_locations(
    state_name="Utah"
)
display(UTsites[0])
# Out:
# Retrieving: monitoring-locations · 1 page · 32,827 rows
#       monitoring_location_id                     geometry agency_code  \
# 0             USBLM-09337800   POINT (-111.4185 37.77554)       USBLM
# 1             USBLM-09337810   POINT (-111.41517 37.6261)       USBLM
# 2      USEPA-370150112583201  POINT (-112.97633 37.03054)       USEPA
# 3      USEPA-370427111405201  POINT (-111.68111 37.07417)       USEPA
# 4      USEPA-370511111410001  POINT (-111.68333 37.08639)       USEPA
# ...                      ...                          ...         ...
# 32822   USGS-415956112532501   POINT (-112.8911 41.99881)        USGS
# 32823   USGS-415957112411001  POINT (-112.68692 41.99909)        USGS
# 32824   USGS-415958111242901  POINT (-111.40882 41.99938)        USGS
# 32825   USGS-415958112390301  POINT (-112.65164 41.99936)        USGS
# 32826          USGS-88101353  POINT (-112.07028 40.70222)        USGS
#
#                                 agency_name monitoring_location_number  \
# 0            U.S. Bureau of Land Management                   09337800
# 1            U.S. Bureau of Land Management                   09337810
# 2      U.S. Environmental Protection Agency            370150112583201
# 3      U.S. Environmental Protection Agency            370427111405201
# 4      U.S. Environmental Protection Agency            370511111410001
# ...                                     ...                        ...
# 32822                U.S. Geological Survey            415956112532501
# 32823                U.S. Geological Survey            415957112411001
# 32824                U.S. Geological Survey            415958111242901
# 32825                U.S. Geological Survey            415958112390301
# 32826                U.S. Geological Survey                   88101353
#
#                              monitoring_location_name district_code  \
# 0      Escalante River above Calf Creek, near Boulder            49
# 1                        Calf Creek at BLM campground            49
# 2                                    (C-43-21)10cbd-1            49
# 3                                    (D-43-15) 2bad-1            49
# 4                                    (D-43-10) 2bdc-1            49
# ...                                               ...           ...
# 32822                               (B-15- 9)29dbc- 1            49
# 32823                               (B-15- 7)30cbc- 1            49
# 32824                               (A-15- 5)32dbb- 1            49
# 32825                               (B-15- 7)29dac- 1            49
# 32826       Carla Bartholoma Test Site at Magna, Utah            49
#
#       country_code              country_name state_code  ...  \
# 0               US  United States of America         49  ...
# 1               US  United States of America         49  ...
# 2               US  United States of America         49  ...
# 3               US  United States of America         49  ...
# 4               US  United States of America         49  ...
# ...            ...                       ...        ...  ...
# 32822           US  United States of America         49  ...
# 32823           US  United States of America         49  ...
# 32824           US  United States of America         49  ...
# 32825           US  United States of America         49  ...
# 32826           US  United States of America         49  ...
#
#       construction_date aquifer_code national_aquifer_code aquifer_type_code  \
# 0                   NaT          NaN                   NaN               NaN
# 1                   NaT          NaN                   NaN               NaN
# 2                   NaT          NaN                   NaN               NaN
# 3                   NaT          NaN                   NaN               NaN
# 4                   NaT          NaN                   NaN               NaN
# ...                 ...          ...                   ...               ...
# 32822        1966-01-01      100VLFL                   NaN               NaN
# 32823        1936-01-01      100VLFL                   NaN               NaN
# 32824        1975-06-12          NaN                   NaN               NaN
# 32825        1966-01-01      100VLFL                   NaN               NaN
# 32826               NaT          NaN                   NaN               NaN
#
#       well_constructed_depth hole_constructed_depth depth_source_code  \
# 0                        NaN                    NaN               NaN
# 1                        NaN                    NaN               NaN
# 2                        NaN                    NaN               NaN
# 3                        NaN                    NaN               NaN
# 4                        NaN                    NaN               NaN
# ...                      ...                    ...               ...
# 32822                  480.0                    NaN                 O
# 32823                  228.0                    NaN               NaN
# 32824                  191.0                  191.0               NaN
# 32825                  175.0                    NaN               NaN
# 32826                    NaN                    NaN               NaN
#
#       revision_note  revision_created  revision_modified
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
# ...             ...               ...                ...
# 32822           NaN               NaN                NaN
# 32823           NaN               NaN                NaN
# 32824           NaN               NaN                NaN
# 32825           NaN               NaN                NaN
# 32826           NaN               NaN                NaN
#
# [32827 rows x 44 columns]

# %% [markdown]
# #### Example 5: Retrieve the time series metadata for a single site
#
# The `get_time_series_metadata()` function lists the parameters that have been collected at a monitoring location.

# %%
oneSite = waterdata.get_time_series_metadata(monitoring_location_id="USGS-05114000")
display(oneSite[0])
# Out:
# Retrieving: time-series-metadata · 1 page · 25 rows
#                       time_series_id                     geometry  \
# 0   02209cc1da684d43a85f6985a68eee5a  POINT (-101.95833 48.98996)
# 1   0a228ec2b10b4e35a94776cb2b19a729  POINT (-101.95833 48.98996)
# 2   15aa662f7df54dd8a1fda8ed030f6155  POINT (-101.95833 48.98996)
# 3   1f227161b9a844769989013bc2961bc7  POINT (-101.95833 48.98996)
# 4   39fe84674f56420fbb26b30ab446a56b  POINT (-101.95833 48.98996)
# 5   3eafa55565f14fd18908405ee299d7aa  POINT (-101.95833 48.98996)
# 6   4edea217371e4a12836f55617fc0a12b  POINT (-101.95833 48.98996)
# 7   524bb4c0ff9d45c5a4eef80b139dbf60  POINT (-101.95833 48.98996)
# 8   6a47b96521c946bebbcb73b4fc6f3538  POINT (-101.95833 48.98996)
# 9   725d1146f5844e6dac62047020546b60  POINT (-101.95833 48.98996)
# 10  74efbbe7893044e8a5463e8d5f752292  POINT (-101.95833 48.98996)
# 11  987c2d767a5a4981acffd51fa253b63b  POINT (-101.95833 48.98996)
# 12  a58dbf3513734ebd91c9e27d38c121f5  POINT (-101.95833 48.98996)
# 13  a6364a8689b546bd9d2d897f8179da47  POINT (-101.95833 48.98996)
# 14  ac8bf082bf9a496e89cad5debf5bb38a  POINT (-101.95833 48.98996)
# 15  b045f9635b3b49379e81fcc045847f39  POINT (-101.95833 48.98996)
# 16  bab51ad615744962956cd824a31572fb  POINT (-101.95833 48.98996)
# 17  bc427f184c4d4478b5761c02f2cb3e07  POINT (-101.95833 48.98996)
# 18  c1031f7855d54510a1e242aeb7ac36e1  POINT (-101.95833 48.98996)
# 19  c170835ac7354feaa6fc42232e7c4d91  POINT (-101.95833 48.98996)
# 20  d5a1ccfc54134bce81f37f14b60f4434  POINT (-101.95833 48.98996)
# 21  d784cef304cf4296af5c3bad7da3e7bf  POINT (-101.95833 48.98996)
# 22  e6bb2ca919aa462cabb7fe13147b2897  POINT (-101.95833 48.98996)
# 23  f631082503074085ac183599f79c4fa3  POINT (-101.95833 48.98996)
# 24  f812872c670d479090e1f9c81f691ea6  POINT (-101.95833 48.98996)
#
#    unit_of_measure        parameter_name parameter_code statistic_id  \
# 0             degC    Temperature, water          00010        00003
# 1           ft^3/s             Discharge          00060          NaN
# 2            uS/cm  Specific cond at 25C          00095        00011
# 3               ft  Stream level, NAVD88          63160        00011
# 4            uS/cm  Specific cond at 25C          00095        00003
# 5             mg/l      Dissolved oxygen          00300        00001
# 6               ft           Gage height          00065        00011
# 7             mg/l      Dissolved oxygen          00300        00003
# 8             degC    Temperature, water          00010        00011
# 9            uS/cm  Specific cond at 25C          00095        00001
# 10            mg/l      Dissolved oxygen          00300        00011
# 11          ft^3/s             Discharge          00060        00011
# 12        tons/day   Suspnd sedmnt disch          80155        00003
# 13            degC    Temperature, water          00010        00002
# 14            mg/l    Suspnd sedmnt conc          80154        00003
# 15              ft           Gage height          00065        00003
# 16        pH Units                    pH          00400        00002
# 17            degC    Temperature, water          00010        00011
# 18          ft^3/s             Discharge          00060        00003
# 19        pH Units                    pH          00400        00001
# 20           uS/cm  Specific cond at 25C          00095        00011
# 21           uS/cm  Specific cond at 25C          00095        00002
# 22            degC    Temperature, water          00010        00001
# 23            mg/l      Dissolved oxygen          00300        00002
# 24              ft           Gage height          00065          NaN
#
#    hydrologic_unit_code    state_name              last_modified  \
# 0          090100080904  North Dakota 2025-09-02 13:13:38.140331
# 1          090100080904  North Dakota 2026-04-23 16:10:53.560921
# 2          090100080904  North Dakota 2026-03-17 18:13:09.673125
# 3          090100080904  North Dakota 2026-05-31 08:13:03.261959
# 4          090100080904  North Dakota 2025-08-07 11:19:28.658052
# 5          090100080904  North Dakota 2023-11-17 17:44:53.028393
# 6          090100080904  North Dakota 2026-05-31 08:12:36.172888
# 7          090100080904  North Dakota 2023-11-17 17:44:53.049018
# 8          090100080904  North Dakota 2026-03-17 18:13:21.767938
# 9          090100080904  North Dakota 2025-08-07 11:19:29.235786
# 10         090100080904  North Dakota 2026-03-17 18:12:59.439628
# 11         090100080904  North Dakota 2026-05-31 07:13:46.966130
# 12         090100080904  North Dakota 2017-05-13 14:48:30.048999
# 13         090100080904  North Dakota 2025-09-02 13:13:38.839970
# 14         090100080904  North Dakota 2017-05-13 14:53:34.288626
# 15         090100080904  North Dakota 2026-06-01 00:12:58.333748
# 16         090100080904  North Dakota 2017-05-13 14:50:10.025905
# 17         090100080904  North Dakota 2017-05-13 14:52:28.127057
# 18         090100080904  North Dakota 2026-05-31 06:14:08.040152
# 19         090100080904  North Dakota 2017-05-13 14:50:04.064455
# 20         090100080904  North Dakota 2017-05-13 14:51:12.739716
# 21         090100080904  North Dakota 2025-08-07 11:19:29.244018
# 22         090100080904  North Dakota 2025-09-02 13:13:38.893858
# 23         090100080904  North Dakota 2023-11-17 17:44:53.039108
# 24         090100080904  North Dakota 2026-03-22 00:18:02.798534
#
#                         begin  ...                   end_utc  \
# 0  1983-08-11 00:00:00.000001  ... 2024-10-31 05:00:00+00:00
# 1  1930-04-11 00:00:00.000001  ... 2025-05-25 05:00:00+00:00
# 2  2019-05-15 15:00:00.000001  ... 2023-10-11 03:15:00+00:00
# 3  2026-01-31 08:45:00.000001  ... 2026-05-31 13:00:00+00:00
# 4  1983-08-11 00:00:00.000001  ... 2023-10-09 05:00:00+00:00
# 5  1993-05-15 00:00:00.000001  ... 2023-10-09 05:00:00+00:00
# 6  2007-10-01 06:30:00.000001  ... 2026-05-31 13:00:00+00:00
# 7  1993-05-15 00:00:00.000001  ... 2023-10-09 05:00:00+00:00
# 8  2019-05-15 15:00:00.000001  ... 2024-11-01 10:45:00+00:00
# 9  1983-08-11 00:00:00.000001  ... 2023-10-09 05:00:00+00:00
# 10 2019-05-15 15:00:00.000001  ... 2023-10-11 03:15:00+00:00
# 11 1994-10-01 06:00:00.000001  ... 2026-05-31 12:00:00+00:00
# 12 1974-10-01 00:00:00.000001  ... 1981-09-29 05:00:00+00:00
# 13 1983-08-11 00:00:00.000001  ... 2024-10-31 05:00:00+00:00
# 14 1974-10-01 00:00:00.000001  ... 1981-09-29 05:00:00+00:00
# 15 2000-10-01 00:00:00.000001  ... 2026-05-30 05:00:00+00:00
# 16 1992-08-12 00:00:00.000001  ... 2003-09-29 05:00:00+00:00
# 17                        NaT  ...                       NaT
# 18 1930-03-11 00:00:00.000001  ... 2026-05-29 05:00:00+00:00
# 19 1992-08-12 00:00:00.000001  ... 2003-09-29 05:00:00+00:00
# 20                        NaT  ...                       NaT
# 21 1983-08-11 00:00:00.000001  ... 2023-10-09 05:00:00+00:00
# 22 1983-08-11 00:00:00.000001  ... 2024-10-31 05:00:00+00:00
# 23 1993-05-15 00:00:00.000001  ... 2023-10-09 05:00:00+00:00
# 24 1904-01-01 00:00:00.000001  ... 2025-05-25 05:00:00+00:00
#
#    computation_period_identifier computation_identifier  \
# 0                          Daily                   Mean
# 1                     Water Year      Max At Event Time
# 2                         Points          Instantaneous
# 3                         Points          Instantaneous
# 4                          Daily                   Mean
# 5                          Daily                    Max
# 6                         Points          Instantaneous
# 7                          Daily                   Mean
# 8                         Points          Instantaneous
# 9                          Daily                    Max
# 10                        Points          Instantaneous
# 11                        Points          Instantaneous
# 12                         Daily                   Mean
# 13                         Daily                    Min
# 14                         Daily                   Mean
# 15                         Daily                   Mean
# 16                         Daily                    Min
# 17                         Daily          Instantaneous
# 18                         Daily                   Mean
# 19                         Daily                    Max
# 20                         Daily          Instantaneous
# 21                         Daily                    Min
# 22                         Daily                    Max
# 23                         Daily                    Min
# 24                    Water Year      Max At Event Time
#
#                                            thresholds sublocation_identifier  \
# 0                                                  []                   None
# 1                                                  []                   None
# 2   [{'Name': 'VERY LOW', 'Type': 'ThresholdBelow'...                   None
# 3                                                  []                   None
# 4                                                  []                   None
# 5                                                  []                   None
# 6   [{'Name': 'Operational limit (maximum) Instrum...                   None
# 7                                                  []                   None
# 8   [{'Name': 'VERY LOW', 'Type': 'ThresholdBelow'...                   None
# 9                                                  []                   None
# 10  [{'Name': 'VERY HIGH', 'Type': 'ThresholdAbove...                   None
# 11  [{'Name': 'VERY HIGH', 'Type': 'ThresholdAbove...                   None
# 12                                                 []                   None
# 13                                                 []                   None
# 14                                                 []                   None
# 15                                                 []                   None
# 16                                                 []                   None
# 17                                                 []                   None
# 18                                                 []                   None
# 19                                                 []                   None
# 20                                                 []                   None
# 21                                                 []                   None
# 22                                                 []                   None
# 23                                                 []                   None
# 24                                                 []                   None
#
#     primary monitoring_location_id web_description  \
# 0   Primary          USGS-05114000            None
# 1   Primary          USGS-05114000            None
# 2   Primary          USGS-05114000            None
# 3       NaN          USGS-05114000            None
# 4   Primary          USGS-05114000            None
# 5   Primary          USGS-05114000            None
# 6   Primary          USGS-05114000            None
# 7   Primary          USGS-05114000            None
# 8   Primary          USGS-05114000            None
# 9   Primary          USGS-05114000            None
# 10  Primary          USGS-05114000            None
# 11  Primary          USGS-05114000            None
# 12  Primary          USGS-05114000            None
# 13  Primary          USGS-05114000            None
# 14  Primary          USGS-05114000            None
# 15  Primary          USGS-05114000            None
# 16  Primary          USGS-05114000            None
# 17  Primary          USGS-05114000            None
# 18  Primary          USGS-05114000            None
# 19  Primary          USGS-05114000            None
# 20  Primary          USGS-05114000            None
# 21  Primary          USGS-05114000            None
# 22  Primary          USGS-05114000            None
# 23  Primary          USGS-05114000            None
# 24  Primary          USGS-05114000            None
#
#                                 parameter_description  \
# 0                 Temperature, water, degrees Celsius
# 1                    Discharge, cubic feet per second
# 2   Specific conductance, water, unfiltered, micro...
# 3   Stream water level elevation above NAVD 1988, ...
# 4   Specific conductance, water, unfiltered, micro...
# 5   Dissolved oxygen, water, unfiltered, milligram...
# 6                                   Gage height, feet
# 7   Dissolved oxygen, water, unfiltered, milligram...
# 8                 Temperature, water, degrees Celsius
# 9   Specific conductance, water, unfiltered, micro...
# 10  Dissolved oxygen, water, unfiltered, milligram...
# 11                   Discharge, cubic feet per second
# 12   Suspended sediment discharge, short tons per day
# 13                Temperature, water, degrees Celsius
# 14  Suspended sediment concentration, milligrams p...
# 15                                  Gage height, feet
# 16       pH, water, unfiltered, field, standard units
# 17                Temperature, water, degrees Celsius
# 18                   Discharge, cubic feet per second
# 19       pH, water, unfiltered, field, standard units
# 20  Specific conductance, water, unfiltered, micro...
# 21  Specific conductance, water, unfiltered, micro...
# 22                Temperature, water, degrees Celsius
# 23  Dissolved oxygen, water, unfiltered, milligram...
# 24                                  Gage height, feet
#
#                parent_time_series_id
# 0   6a47b96521c946bebbcb73b4fc6f3538
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4   15aa662f7df54dd8a1fda8ed030f6155
# 5   74efbbe7893044e8a5463e8d5f752292
# 6                                NaN
# 7   74efbbe7893044e8a5463e8d5f752292
# 8                                NaN
# 9   15aa662f7df54dd8a1fda8ed030f6155
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13  6a47b96521c946bebbcb73b4fc6f3538
# 14                               NaN
# 15  4edea217371e4a12836f55617fc0a12b
# 16                               NaN
# 17                               NaN
# 18  987c2d767a5a4981acffd51fa253b63b
# 19                               NaN
# 20                               NaN
# 21  15aa662f7df54dd8a1fda8ed030f6155
# 22  6a47b96521c946bebbcb73b4fc6f3538
# 23  74efbbe7893044e8a5463e8d5f752292
# 24                               NaN
#
# [25 rows x 22 columns]
